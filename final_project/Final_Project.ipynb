# %% [markdown]
# # Final Project: Attention is also Needed for Time Series
# Author: Hongda Yuan
#
# ## Access Hugging Face

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# ...
# Token has not been saved to git credential helper.
